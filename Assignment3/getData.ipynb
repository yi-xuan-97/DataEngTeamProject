# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from lxml import etree

pageurl = 'http://www.psudataeng.com:8000/getStopEvents/'
s = requests.Session()
resp = s.get(url = pageurl)
soup = BeautifulSoup(resp.text,'html.parser')
allTable = soup.find_all('table')
print(len(allTable))
# Out:
# 1504

# %%
records = []
def tableformtodict(table):
    s = str(table)
    table = etree.HTML(s).find("body/table")
    rows = iter(table)
    headers = [col.text for col in next(rows)]
    for row in rows:
        values = [col.text for col in row]
        records.append(dict(zip(headers, values)))
for table in allTable:
    tableformtodict(table)
records
# Out:
# [{'vehicle_number': '2224',
#   'leave_time': '31928',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '31920',
#   'arrive_time': '31928',
#   'dwell': '0',
#   'location_id': '940',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '0',
#   'pattern_distance': '0',
#   'location_distance': '14.270249',
#   'x_coordinate': '-122.67722499999999',
#   'y_coordinate': '45.519565',
#   'data_source': '2',
#   'schedule_status': '5'},
#  {'vehicle_number': '2224',
#   'leave_time': '32402',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '32400',
#   'arrive_time': '32402',
#   'dwell': '0',
#   'location_id': None,
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '2.854',
#   'pattern_distance': '2.849',
#   'location_distance': '13.309048',
#   'x_coordinate': '-122.66536',
#   'y_coordinate': '45.5231',
#   'data_source': '1',
#   'schedule_status': '4'},
#  {'vehicle_number': '2224',
#   'leave_time': '32683',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '32640',
#   'arrive_time': '32683',
#   'dwell': '0',
#   'location_id': None,
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '6.7711',
#   'pattern_distance': '6.7872',
#   'location_distance': '75.045969',
#   'x_coordinate': '-122.67852833333333',
#   'y_coordinate': '45.57750166666667',
#   'data_source': '1',
#   'schedule_status': '4'},
#  {'vehicle_number': '2224',
#   'leave_time': '33072',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '33000',
#   'arrive_time': '33072',
#   'dwell': '0',
#   'location_id': '908',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '10.7261',
#   'pattern_distance': '10.8063',
#   'location_distance': '103.588889',
#   'x_coordinate': '-122.67055833333333',
#   'y_coordinate': '45.62878166666667',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '2224',
#   'leave_time': '33116',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '33116',
#   'dwell': '0',
#   'location_id': '910',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '10.9256',
#   'pattern_distance': '11.0008',
#   'location_distance': '64.894642',
#   'x_coordinate': '-122.67050666666667',
#   'y_coordinate': '45.631503333333335',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2224',
#   'leave_time': '33027',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '33027',
#   'dwell': '0',
#   'location_id': '906',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '10.6727',
#   'pattern_distance': '10.6509',
#   'location_distance': '628.770844',
#   'x_coordinate': '-122.67057',
#   'y_coordinate': '45.627975',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2224',
#   'leave_time': '32033',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '31973',
#   'dwell': '60',
#   'location_id': '944',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '0.1951',
#   'pattern_distance': '0.1895',
#   'location_distance': '5.482481',
#   'x_coordinate': '-122.67867166666667',
#   'y_coordinate': '45.51694333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2224',
#   'leave_time': '33666',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '33720',
#   'arrive_time': '33666',
#   'dwell': '0',
#   'location_id': '877',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '15.9102',
#   'pattern_distance': '16.1072',
#   'location_distance': '133.999838',
#   'x_coordinate': '-122.66373333333334',
#   'y_coordinate': '45.69063666666667',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '2224',
#   'leave_time': '32110',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '32096',
#   'dwell': '14',
#   'location_id': '948',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '0.4412',
#   'pattern_distance': '0.4356',
#   'location_distance': '20.553069',
#   'x_coordinate': '-122.68052333333333',
#   'y_coordinate': '45.513646666666666',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2224',
#   'leave_time': '32228',
#   'train': '9004',
#   'route_number': '105',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '32220',
#   'arrive_time': '32167',
#   'dwell': '61',
#   'location_id': '963',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '0.6866',
#   'pattern_distance': '0.6848',
#   'location_distance': '21.024173',
#   'x_coordinate': '-122.68229833333334',
#   'y_coordinate': '45.51022',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '2224',
#   'leave_time': '33733',
#   'train': '9004',
#   'route_number': '105',
#   'direction': None,
#   'service_key': 'W',
#   'stop_time': '34200',
#   'arrive_time': '33733',
#   'dwell': '0',
#   'location_id': '177',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '0',
#   'maximum_speed': None,
#   'train_mileage': '0',
#   'pattern_distance': None,
#   'location_distance': '11311.788774',
#   'x_coordinate': '-122.66374',
#   'y_coordinate': '45.690615',
#   'data_source': '2',
#   'schedule_status': '0'},
#  {'vehicle_number': '4037',
#   'leave_time': '16593',
#   'train': '7801',
#   'route_number': '78',
#   'direction': None,
#   'service_key': 'W',
#   'stop_time': '17100',
#   'arrive_time': '16593',
#   'dwell': '0',
#   'location_id': '877',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '1',
#   'estimated_load': '0',
#   'maximum_speed': None,
#   'train_mileage': '0',
#   'pattern_distance': None,
#   'location_distance': '70.384025',
#   'x_coordinate': '-122.66406166666667',
#   'y_coordinate': '45.69014833333333',
#   'data_source': '2',
#   'schedule_status': '0'},
#  {'vehicle_number': '4037',
#   'leave_time': '17857',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17857',
#   'dwell': '0',
#   'location_id': '544',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '4.8902',
#   'pattern_distance': '4.9492',
#   'location_distance': '169.621711',
#   'x_coordinate': '-122.60326666666667',
#   'y_coordinate': '45.672891666666665',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '18169',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '18420',
#   'arrive_time': '18169',
#   'dwell': '0',
#   'location_id': '1095',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '2',
#   'estimated_load': '0',
#   'maximum_speed': None,
#   'train_mileage': '6.9239',
#   'pattern_distance': '7.0606',
#   'location_distance': '211.434035',
#   'x_coordinate': '-122.58486666666667',
#   'y_coordinate': '45.65624',
#   'data_source': '2',
#   'schedule_status': '6'},
#  {'vehicle_number': '4037',
#   'leave_time': '17480',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17480',
#   'dwell': '0',
#   'location_id': '554',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '2.5134',
#   'pattern_distance': '2.5458',
#   'location_distance': '11.630465',
#   'x_coordinate': '-122.64388',
#   'y_coordinate': '45.678621666666665',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17728',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17728',
#   'dwell': '0',
#   'location_id': '548',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '3.6027',
#   'pattern_distance': '3.6599',
#   'location_distance': '15.75479',
#   'x_coordinate': '-122.62085833333333',
#   'y_coordinate': '45.678646666666666',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17277',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17277',
#   'dwell': '0',
#   'location_id': '539',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '1.0408',
#   'pattern_distance': '1.0762',
#   'location_distance': '117.774163',
#   'x_coordinate': '-122.66021833333333',
#   'y_coordinate': '45.68667666666666',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17429',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17429',
#   'dwell': '0',
#   'location_id': '556',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '1.8977',
#   'pattern_distance': '1.9592',
#   'location_distance': '85.223483',
#   'x_coordinate': '-122.65634333333334',
#   'y_coordinate': '45.678486666666664',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17412',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '17400',
#   'arrive_time': '17370',
#   'dwell': '42',
#   'location_id': '558',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '1.7429',
#   'pattern_distance': '1.8281',
#   'location_distance': '28.365075',
#   'x_coordinate': '-122.658645',
#   'y_coordinate': '45.678466666666665',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '4037',
#   'leave_time': '17510',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17510',
#   'dwell': '0',
#   'location_id': '594',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '2.8844',
#   'pattern_distance': '2.9316',
#   'location_distance': '52.502488',
#   'x_coordinate': '-122.63615',
#   'y_coordinate': '45.678675',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17124',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '17100',
#   'arrive_time': '17124',
#   'dwell': '0',
#   'location_id': '877',
#   'door': '1',
#   'lift': '0',
#   'ons': '1',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '0',
#   'pattern_distance': '0',
#   'location_distance': '45.472619',
#   'x_coordinate': '-122.66403833333334',
#   'y_coordinate': '45.690265',
#   'data_source': '2',
#   'schedule_status': '5'},
#  {'vehicle_number': '4037',
#   'leave_time': '17290',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17290',
#   'dwell': '0',
#   'location_id': '542',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '1.1837',
#   'pattern_distance': '1.2365',
#   'location_distance': '186.841105',
#   'x_coordinate': '-122.66082333333334',
#   'y_coordinate': '45.685226666666665',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17793',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17793',
#   'dwell': '0',
#   'location_id': '591',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '4.3477',
#   'pattern_distance': '4.4099',
#   'location_distance': '79.250528',
#   'x_coordinate': '-122.60514666666667',
#   'y_coordinate': '45.67878',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17894',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17894',
#   'dwell': '0',
#   'location_id': '175',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '5.3003',
#   'pattern_distance': '5.3637',
#   'location_distance': '93.055516',
#   'x_coordinate': '-122.60229',
#   'y_coordinate': '45.667208333333335',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '18031',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '18031',
#   'dwell': '0',
#   'location_id': '780',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '6.1895',
#   'pattern_distance': '6.3051',
#   'location_distance': '34.043944',
#   'x_coordinate': '-122.59647166666667',
#   'y_coordinate': '45.657645',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17248',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17248',
#   'dwell': '0',
#   'location_id': '536',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '0.7189',
#   'pattern_distance': '0.75',
#   'location_distance': '62.608953',
#   'x_coordinate': '-122.657735',
#   'y_coordinate': '45.69123',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17307',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17307',
#   'dwell': '0',
#   'location_id': '762',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '1.3707',
#   'pattern_distance': '1.4198',
#   'location_distance': '72.933107',
#   'x_coordinate': '-122.66156166666667',
#   'y_coordinate': '45.68191',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '18044',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '18044',
#   'dwell': '0',
#   'location_id': '818',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '6.3256',
#   'pattern_distance': '6.4355',
#   'location_distance': '113.436077',
#   'x_coordinate': '-122.59430833333333',
#   'y_coordinate': '45.65768',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17495',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17495',
#   'dwell': '0',
#   'location_id': '551',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '2.6999',
#   'pattern_distance': '2.7465',
#   'location_distance': '60.445896',
#   'x_coordinate': '-122.64001166666667',
#   'y_coordinate': '45.678668333333334',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17757',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17757',
#   'dwell': '0',
#   'location_id': '546',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '3.9364',
#   'pattern_distance': '3.9979',
#   'location_distance': '86.175455',
#   'x_coordinate': '-122.61362',
#   'y_coordinate': '45.67872333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17822',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17822',
#   'dwell': '0',
#   'location_id': '139',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '4.5074',
#   'pattern_distance': '4.5851',
#   'location_distance': '99.646124',
#   'x_coordinate': '-122.60224666666667',
#   'y_coordinate': '45.678255',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17914',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17914',
#   'dwell': '0',
#   'location_id': '173',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '5.5321',
#   'pattern_distance': '5.6035',
#   'location_distance': '13.346778',
#   'x_coordinate': '-122.60228166666667',
#   'y_coordinate': '45.663956666666664',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '18056',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '18056',
#   'dwell': '0',
#   'location_id': '168',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '6.4573',
#   'pattern_distance': '6.5673',
#   'location_distance': '59.715041',
#   'x_coordinate': '-122.591055',
#   'y_coordinate': '45.658188333333335',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17441',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17441',
#   'dwell': '0',
#   'location_id': '574',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '2.0219',
#   'pattern_distance': '2.0754',
#   'location_distance': '154.948498',
#   'x_coordinate': '-122.65421666666667',
#   'y_coordinate': '45.678495',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '17707',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '17700',
#   'arrive_time': '17576',
#   'dwell': '131',
#   'location_id': '549',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '3.374',
#   'pattern_distance': '3.4666',
#   'location_distance': '71.254198',
#   'x_coordinate': '-122.62462166666667',
#   'y_coordinate': '45.678671666666666',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '4037',
#   'leave_time': '18010',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '17999',
#   'dwell': '11',
#   'location_id': '171',
#   'door': '1',
#   'lift': '0',
#   'ons': '1',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '6.0236',
#   'pattern_distance': '6.1534',
#   'location_distance': '9.401748',
#   'x_coordinate': '-122.59974833333334',
#   'y_coordinate': '45.65764166666666',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19487',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19487',
#   'dwell': '0',
#   'location_id': '176',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '1.8548',
#   'pattern_distance': '1.9436',
#   'location_distance': '69.017909',
#   'x_coordinate': '-122.60220666666666',
#   'y_coordinate': '45.66865166666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19903',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19903',
#   'dwell': '0',
#   'location_id': '807',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '3.8457',
#   'pattern_distance': '3.978',
#   'location_distance': '181.080027',
#   'x_coordinate': '-122.627765',
#   'y_coordinate': '45.67883666666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19955',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19955',
#   'dwell': '0',
#   'location_id': '552',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '4.4938',
#   'pattern_distance': '4.6187',
#   'location_distance': '121.324935',
#   'x_coordinate': '-122.64217',
#   'y_coordinate': '45.678826666666666',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '20008',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '20008',
#   'dwell': '0',
#   'location_id': '557',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '5.1549',
#   'pattern_distance': '5.3084',
#   'location_distance': '139.04517',
#   'x_coordinate': '-122.6554',
#   'y_coordinate': '45.67866333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '20027',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '20027',
#   'dwell': '0',
#   'location_id': '258',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '5.3587',
#   'pattern_distance': '5.5097',
#   'location_distance': '59.849713',
#   'x_coordinate': '-122.65987166666666',
#   'y_coordinate': '45.67865833333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19332',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19332',
#   'dwell': '0',
#   'location_id': '167',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '0.5605',
#   'pattern_distance': '0.6437',
#   'location_distance': '23.406673',
#   'x_coordinate': '-122.59065166666667',
#   'y_coordinate': '45.658343333333335',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19517',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19517',
#   'dwell': '0',
#   'location_id': '545',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '2.1854',
#   'pattern_distance': '2.2922',
#   'location_distance': '28.876685',
#   'x_coordinate': '-122.60316',
#   'y_coordinate': '45.67331333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19574',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19574',
#   'dwell': '0',
#   'location_id': '590',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '2.6091',
#   'pattern_distance': '2.721',
#   'location_distance': '166.669508',
#   'x_coordinate': '-122.603885',
#   'y_coordinate': '45.678895',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '20200',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '20200',
#   'dwell': '0',
#   'location_id': '541',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '5.8769',
#   'pattern_distance': '6.036',
#   'location_distance': '66.164514',
#   'x_coordinate': '-122.66072833333334',
#   'y_coordinate': '45.68487666666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '20468',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '20640',
#   'arrive_time': '20468',
#   'dwell': '0',
#   'location_id': '877',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '2',
#   'estimated_load': '0',
#   'maximum_speed': None,
#   'train_mileage': '7.0358',
#   'pattern_distance': '7.2974',
#   'location_distance': '137.432581',
#   'x_coordinate': '-122.66405166666667',
#   'y_coordinate': '45.689928333333334',
#   'data_source': '2',
#   'schedule_status': '6'},
#  {'vehicle_number': '4037',
#   'leave_time': '19407',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19407',
#   'dwell': '0',
#   'location_id': '172',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '1.1197',
#   'pattern_distance': '1.2191',
#   'location_distance': '32.035274',
#   'x_coordinate': '-122.60207333333334',
#   'y_coordinate': '45.658035',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19375',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19375',
#   'dwell': '0',
#   'location_id': '170',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '0.9476',
#   'pattern_distance': '1.0526',
#   'location_distance': '6.568545',
#   'x_coordinate': '-122.59904666666667',
#   'y_coordinate': '45.65775333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '20226',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '20226',
#   'dwell': '0',
#   'location_id': '538',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '6.1659',
#   'pattern_distance': '6.3237',
#   'location_distance': '31.865878',
#   'x_coordinate': '-122.65889333333334',
#   'y_coordinate': '45.68873333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '20237',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '20237',
#   'dwell': '0',
#   'location_id': '537',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '6.2839',
#   'pattern_distance': '6.4728',
#   'location_distance': '157.07048',
#   'x_coordinate': '-122.65804666666666',
#   'y_coordinate': '45.69027666666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19362',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19362',
#   'dwell': '0',
#   'location_id': '169',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '0.8314',
#   'pattern_distance': '0.9165',
#   'location_distance': '31.162905',
#   'x_coordinate': '-122.59624333333333',
#   'y_coordinate': '45.65777166666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19995',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19995',
#   'dwell': '0',
#   'location_id': '555',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '5.0163',
#   'pattern_distance': '5.1549',
#   'location_distance': '78.780584',
#   'x_coordinate': '-122.65307333333334',
#   'y_coordinate': '45.678685',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '20168',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '20160',
#   'arrive_time': '20065',
#   'dwell': '103',
#   'location_id': '760',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '5.5184',
#   'pattern_distance': '5.7179',
#   'location_distance': '15.014047',
#   'x_coordinate': '-122.66170166666667',
#   'y_coordinate': '45.680148333333335',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '4037',
#   'leave_time': '19223',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '19200',
#   'arrive_time': '19223',
#   'dwell': '0',
#   'location_id': '1095',
#   'door': '1',
#   'lift': '0',
#   'ons': '1',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '0',
#   'pattern_distance': '0',
#   'location_distance': '126.230037',
#   'x_coordinate': '-122.58449166666666',
#   'y_coordinate': '45.65633666666667',
#   'data_source': '2',
#   'schedule_status': '5'},
#  {'vehicle_number': '4037',
#   'leave_time': '19461',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19461',
#   'dwell': '0',
#   'location_id': '174',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '1.5963',
#   'pattern_distance': '1.6765',
#   'location_distance': '175.488793',
#   'x_coordinate': '-122.6021',
#   'y_coordinate': '45.66507',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19632',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19632',
#   'dwell': '0',
#   'location_id': '547',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '3.0447',
#   'pattern_distance': '3.1547',
#   'location_distance': '93.258787',
#   'x_coordinate': '-122.61255',
#   'y_coordinate': '45.67883166666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19879',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '19860',
#   'arrive_time': '19720',
#   'dwell': '159',
#   'location_id': '782',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '3.5928',
#   'pattern_distance': '3.7587',
#   'location_distance': '65.35812',
#   'x_coordinate': '-122.62418333333333',
#   'y_coordinate': '45.67884166666666',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '4037',
#   'leave_time': '19944',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19944',
#   'dwell': '0',
#   'location_id': '593',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '4.3484',
#   'pattern_distance': '4.4546',
#   'location_distance': '289.453554',
#   'x_coordinate': '-122.63941666666666',
#   'y_coordinate': '45.67884',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '20211',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '20211',
#   'dwell': '0',
#   'location_id': '540',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '5.9956',
#   'pattern_distance': '6.1609',
#   'location_distance': '7.750632',
#   'x_coordinate': '-122.66009833333334',
#   'y_coordinate': '45.68648',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '19975',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '19975',
#   'dwell': '0',
#   'location_id': '553',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '4.7448',
#   'pattern_distance': '4.8622',
#   'location_distance': '177.831132',
#   'x_coordinate': '-122.647415',
#   'y_coordinate': '45.67874833333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '21988',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '21974',
#   'dwell': '14',
#   'location_id': '932',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '1',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '2.2121',
#   'pattern_distance': '2.2786',
#   'location_distance': '36.542421',
#   'x_coordinate': '-122.651375',
#   'y_coordinate': '45.715061666666664',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '22320',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '22320',
#   'dwell': '0',
#   'location_id': '970',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '3.1727',
#   'pattern_distance': '3.2305',
#   'location_distance': '116.867705',
#   'x_coordinate': '-122.64113833333333',
#   'y_coordinate': '45.72192166666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '21814',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '21798',
#   'dwell': '16',
#   'location_id': '535',
#   'door': '1',
#   'lift': '0',
#   'ons': '1',
#   'offs': '0',
#   'estimated_load': '4',
#   'maximum_speed': None,
#   'train_mileage': '0.6823',
#   'pattern_distance': '0.7413',
#   'location_distance': '7.70834',
#   'x_coordinate': '-122.65610666666667',
#   'y_coordinate': '45.69377',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '22385',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '22440',
#   'arrive_time': '22385',
#   'dwell': '0',
#   'location_id': '1044',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '3.6518',
#   'pattern_distance': '3.7835',
#   'location_distance': '15.185404',
#   'x_coordinate': '-122.64097333333333',
#   'y_coordinate': '45.72906166666667',
#   'data_source': '2',
#   'schedule_status': '6'},
#  {'vehicle_number': '4037',
#   'leave_time': '21622',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '21600',
#   'arrive_time': '21622',
#   'dwell': '0',
#   'location_id': '877',
#   'door': '1',
#   'lift': '0',
#   'ons': '3',
#   'offs': '0',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '0',
#   'pattern_distance': '0',
#   'location_distance': '209.353594',
#   'x_coordinate': '-122.66437666666667',
#   'y_coordinate': '45.689836666666665',
#   'data_source': '2',
#   'schedule_status': '5'},
#  {'vehicle_number': '4037',
#   'leave_time': '21838',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '21838',
#   'dwell': '0',
#   'location_id': '808',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '4',
#   'maximum_speed': None,
#   'train_mileage': '0.9084',
#   'pattern_distance': '0.9482',
#   'location_distance': '15.960645',
#   'x_coordinate': '-122.65456666666667',
#   'y_coordinate': '45.696643333333334',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '21850',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '21850',
#   'dwell': '0',
#   'location_id': '759',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '4',
#   'maximum_speed': None,
#   'train_mileage': '1.0371',
#   'pattern_distance': '1.0762',
#   'location_distance': '54.706925',
#   'x_coordinate': '-122.65373333333334',
#   'y_coordinate': '45.698195',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '22280',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': '22260',
#   'arrive_time': '22176',
#   'dwell': '104',
#   'location_id': '859',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '2.9347',
#   'pattern_distance': '3.0242',
#   'location_distance': '28.997567',
#   'x_coordinate': '-122.64573333333334',
#   'y_coordinate': '45.72183833333333',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '4037',
#   'leave_time': '21876',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '21876',
#   'dwell': '0',
#   'location_id': '771',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '4',
#   'maximum_speed': None,
#   'train_mileage': '1.3403',
#   'pattern_distance': '1.3602',
#   'location_distance': '16.887943',
#   'x_coordinate': '-122.651535',
#   'y_coordinate': '45.702216666666665',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '21904',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '21904',
#   'dwell': '0',
#   'location_id': '934',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '4',
#   'maximum_speed': None,
#   'train_mileage': '1.6075',
#   'pattern_distance': '1.6299',
#   'location_distance': '128.293294',
#   'x_coordinate': '-122.64932833333333',
#   'y_coordinate': '45.70614166666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '22153',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '22139',
#   'dwell': '14',
#   'location_id': '855',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '1',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '2.7626',
#   'pattern_distance': '2.8459',
#   'location_distance': '28.334557',
#   'x_coordinate': '-122.649435',
#   'y_coordinate': '45.72181333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '21928',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '21928',
#   'dwell': '0',
#   'location_id': '935',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '4',
#   'maximum_speed': None,
#   'train_mileage': '1.8685',
#   'pattern_distance': '1.8896',
#   'location_distance': '179.873984',
#   'x_coordinate': '-122.64949333333334',
#   'y_coordinate': '45.709985',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '22991',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '22938',
#   'dwell': '53',
#   'location_id': '931',
#   'door': '1',
#   'lift': '0',
#   'ons': '3',
#   'offs': '2',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '2.5097',
#   'pattern_distance': '2.5613',
#   'location_distance': '21.438766',
#   'x_coordinate': '-122.65162833333333',
#   'y_coordinate': '45.71506',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '23120',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '23120',
#   'dwell': '0',
#   'location_id': '530',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '3.1907',
#   'pattern_distance': '3.2193',
#   'location_distance': '113.476167',
#   'x_coordinate': '-122.64983833333334',
#   'y_coordinate': '45.70562833333334',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '22444',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '22440',
#   'arrive_time': '22444',
#   'dwell': '0',
#   'location_id': '1044',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '0',
#   'pattern_distance': '0',
#   'location_distance': '15.229849',
#   'x_coordinate': '-122.64097166666667',
#   'y_coordinate': '45.72906833333333',
#   'data_source': '2',
#   'schedule_status': '5'},
#  {'vehicle_number': '4037',
#   'leave_time': '22764',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '22740',
#   'arrive_time': '22682',
#   'dwell': '82',
#   'location_id': '1046',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '1.8194',
#   'pattern_distance': '1.8647',
#   'location_distance': '56.212085',
#   'x_coordinate': '-122.65146333333334',
#   'y_coordinate': '45.72507',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '4037',
#   'leave_time': '23080',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '23047',
#   'dwell': '33',
#   'location_id': '933',
#   'door': '1',
#   'lift': '0',
#   'ons': '3',
#   'offs': '0',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '2.9248',
#   'pattern_distance': '2.9876',
#   'location_distance': '37.318055',
#   'x_coordinate': '-122.64941333333333',
#   'y_coordinate': '45.709223333333334',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '23143',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '23143',
#   'dwell': '0',
#   'location_id': '531',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '3.3834',
#   'pattern_distance': '3.402',
#   'location_distance': '85.94876',
#   'x_coordinate': '-122.65117',
#   'y_coordinate': '45.70323166666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '23433',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '23520',
#   'arrive_time': '23433',
#   'dwell': '0',
#   'location_id': '877',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '5',
#   'estimated_load': '0',
#   'maximum_speed': None,
#   'train_mileage': '4.7591',
#   'pattern_distance': '4.7945',
#   'location_distance': '76.182056',
#   'x_coordinate': '-122.66407',
#   'y_coordinate': '45.690131666666666',
#   'data_source': '2',
#   'schedule_status': '6'},
#  {'vehicle_number': '4037',
#   'leave_time': '23155',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '23155',
#   'dwell': '0',
#   'location_id': '532',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '3.512',
#   'pattern_distance': '3.5356',
#   'location_distance': '76.224548',
#   'x_coordinate': '-122.65192',
#   'y_coordinate': '45.70183',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '23310',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '23310',
#   'dwell': '0',
#   'location_id': '756',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '4.0979',
#   'pattern_distance': '4.1259',
#   'location_distance': '188.35134',
#   'x_coordinate': '-122.656695',
#   'y_coordinate': '45.693175',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '23194',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '23175',
#   'dwell': '19',
#   'location_id': '533',
#   'door': '1',
#   'lift': '0',
#   'ons': '1',
#   'offs': '0',
#   'estimated_load': '6',
#   'maximum_speed': None,
#   'train_mileage': '3.6158',
#   'pattern_distance': '3.6624',
#   'location_distance': '89.489192',
#   'x_coordinate': '-122.65312333333333',
#   'y_coordinate': '45.699691666666666',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '23242',
#   'train': '7801',
#   'route_number': '19',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '23225',
#   'dwell': '17',
#   'location_id': '534',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '1',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '3.8016',
#   'pattern_distance': '3.8649',
#   'location_distance': '79.888968',
#   'x_coordinate': '-122.654595',
#   'y_coordinate': '45.696978333333334',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '26681',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '26667',
#   'dwell': '14',
#   'location_id': '170',
#   'door': '1',
#   'lift': '0',
#   'ons': '2',
#   'offs': '0',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '0.9302',
#   'pattern_distance': '1.0526',
#   'location_distance': '16.496935',
#   'x_coordinate': '-122.59912',
#   'y_coordinate': '45.65775333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '26753',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '26753',
#   'dwell': '0',
#   'location_id': '174',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '1.5944',
#   'pattern_distance': '1.6765',
#   'location_distance': '9.72297',
#   'x_coordinate': '-122.60211',
#   'y_coordinate': '45.66459666666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '26809',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '26809',
#   'dwell': '0',
#   'location_id': '545',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '5',
#   'maximum_speed': None,
#   'train_mileage': '2.1872',
#   'pattern_distance': '2.2922',
#   'location_distance': '147.35393',
#   'x_coordinate': '-122.60319833333334',
#   'y_coordinate': '45.67379',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '4037',
#   'leave_time': '27140',
#   'train': '7801',
#   'route_number': '78',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '27120',
#   'arrive_time': '27022',
#   'dwell': '118',
#   'location_id': '782',
#   'door': '1',
# ...
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49408',
#   'dwell': '0',
#   'location_id': '287',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '5.1307',
#   'pattern_distance': '5.1996',
#   'location_distance': '188.874154',
#   'x_coordinate': '-122.63803',
#   'y_coordinate': '45.660465',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49449',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49433',
#   'dwell': '16',
#   'location_id': '289',
#   'door': '1',
#   'lift': '0',
#   'ons': '1',
#   'offs': '0',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '5.2966',
#   'pattern_distance': '5.4252',
#   'location_distance': '40.671681',
#   'x_coordinate': '-122.63772333333333',
#   'y_coordinate': '45.657606666666666',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '50135',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '50135',
#   'dwell': '0',
#   'location_id': '660',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '7.4484',
#   'pattern_distance': '7.5776',
#   'location_distance': '20.749183',
#   'x_coordinate': '-122.658885',
#   'y_coordinate': '45.632736666666666',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '50458',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '50431',
#   'dwell': '27',
#   'location_id': '1049',
#   'door': '1',
#   'lift': '0',
#   'ons': '0',
#   'offs': '2',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '8.4649',
#   'pattern_distance': '8.652',
#   'location_distance': '16.141555',
#   'x_coordinate': '-122.677995',
#   'y_coordinate': '45.628875',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '50555',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '50555',
#   'dwell': '0',
#   'location_id': '605',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '8.9018',
#   'pattern_distance': '9.0882',
#   'location_distance': '57.360719',
#   'x_coordinate': '-122.681055',
#   'y_coordinate': '45.63261833333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '48802',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '48802',
#   'dwell': '0',
#   'location_id': '1134',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '1.5224',
#   'pattern_distance': '1.5398',
#   'location_distance': '70.131403',
#   'x_coordinate': '-122.63752333333333',
#   'y_coordinate': '45.69315',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '48835',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '48835',
#   'dwell': '0',
#   'location_id': '562',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '1.8523',
#   'pattern_distance': '1.8722',
#   'location_distance': '179.015397',
#   'x_coordinate': '-122.63022166666667',
#   'y_coordinate': '45.69316',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '48893',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '48893',
#   'dwell': '0',
#   'location_id': '693',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '2.2916',
#   'pattern_distance': '2.3177',
#   'location_distance': '95.27428',
#   'x_coordinate': '-122.62148166666667',
#   'y_coordinate': '45.69275666666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '48928',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '48928',
#   'dwell': '0',
#   'location_id': '1055',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '2.5215',
#   'pattern_distance': '2.5514',
#   'location_distance': '108.180554',
#   'x_coordinate': '-122.61681',
#   'y_coordinate': '45.692295',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49421',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49421',
#   'dwell': '0',
#   'location_id': '288',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '5.2382',
#   'pattern_distance': '5.3264',
#   'location_distance': '45.76133',
#   'x_coordinate': '-122.63801',
#   'y_coordinate': '45.65924833333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49549',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49476',
#   'dwell': '73',
#   'location_id': '290',
#   'door': '1',
#   'lift': '0',
#   'ons': '2',
#   'offs': '1',
#   'estimated_load': '4',
#   'maximum_speed': None,
#   'train_mileage': '5.4674',
#   'pattern_distance': '5.6054',
#   'location_distance': '25.801095',
#   'x_coordinate': '-122.637285',
#   'y_coordinate': '45.655085',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49608',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49608',
#   'dwell': '0',
#   'location_id': '766',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '4',
#   'maximum_speed': None,
#   'train_mileage': '5.9161',
#   'pattern_distance': '6.0049',
#   'location_distance': '185.232456',
#   'x_coordinate': '-122.64013333333334',
#   'y_coordinate': '45.64928333333334',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '50580',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '50520',
#   'arrive_time': '50580',
#   'dwell': '0',
#   'location_id': '823',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '9.0714',
#   'pattern_distance': '9.2541',
#   'location_distance': '135.829737',
#   'x_coordinate': '-122.677615',
#   'y_coordinate': '45.63266',
#   'data_source': '2',
#   'schedule_status': '6'},
#  {'vehicle_number': '2270',
#   'leave_time': '49103',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49103',
#   'dwell': '0',
#   'location_id': '302',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '3.3865',
#   'pattern_distance': '3.4617',
#   'location_distance': '111.260239',
#   'x_coordinate': '-122.625685',
#   'y_coordinate': '45.68235333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '50248',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '50248',
#   'dwell': '0',
#   'location_id': '340',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '7.7187',
#   'pattern_distance': '7.8311',
#   'location_distance': '205.332934',
#   'x_coordinate': '-122.662735',
#   'y_coordinate': '45.62954166666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '50527',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '50527',
#   'dwell': '0',
#   'location_id': '710',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '1',
#   'maximum_speed': None,
#   'train_mileage': '8.7843',
#   'pattern_distance': '8.9415',
#   'location_distance': '174.867201',
#   'x_coordinate': '-122.68143',
#   'y_coordinate': '45.63104',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '48391',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '48300',
#   'arrive_time': '48391',
#   'dwell': '0',
#   'location_id': '877',
#   'door': '1',
#   'lift': '0',
#   'ons': '2',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '0',
#   'pattern_distance': '0',
#   'location_distance': '39.74705',
#   'x_coordinate': '-122.66401333333333',
#   'y_coordinate': '45.690306666666665',
#   'data_source': '2',
#   'schedule_status': '5'},
#  {'vehicle_number': '2270',
#   'leave_time': '48713',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '48713',
#   'dwell': '0',
#   'location_id': '1054',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '0.6562',
#   'pattern_distance': '0.6761',
#   'location_distance': '2.863776',
#   'x_coordinate': '-122.65561666666666',
#   'y_coordinate': '45.69300666666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '48983',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '48983',
#   'dwell': '0',
#   'location_id': '306',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '3.0348',
#   'pattern_distance': '3.0994',
#   'location_distance': '182.667193',
#   'x_coordinate': '-122.62476666666667',
#   'y_coordinate': '45.68666833333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49359',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49359',
#   'dwell': '0',
#   'location_id': '285',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '4.7355',
#   'pattern_distance': '4.81',
#   'location_distance': '95.476672',
#   'x_coordinate': '-122.63816833333334',
#   'y_coordinate': '45.66635',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49373',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49373',
#   'dwell': '0',
#   'location_id': '286',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '4.843',
#   'pattern_distance': '4.93',
#   'location_distance': '97.052691',
#   'x_coordinate': '-122.63826',
#   'y_coordinate': '45.664608333333334',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49907',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49907',
#   'dwell': '0',
#   'location_id': '657',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '6.7425',
#   'pattern_distance': '6.8761',
#   'location_distance': '74.017652',
#   'x_coordinate': '-122.647875',
#   'y_coordinate': '45.63872833333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '48761',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '48761',
#   'dwell': '0',
#   'location_id': '563',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '1.1265',
#   'pattern_distance': '1.1458',
#   'location_distance': '104.589752',
#   'x_coordinate': '-122.645515',
#   'y_coordinate': '45.69309333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49085',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49085',
#   'dwell': '0',
#   'location_id': '305',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '3.2255',
#   'pattern_distance': '3.2964',
#   'location_distance': '72.211661',
#   'x_coordinate': '-122.625635',
#   'y_coordinate': '45.68425166666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '49247',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '49247',
#   'dwell': '0',
#   'location_id': '296',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '3.9755',
#   'pattern_distance': '4.0346',
#   'location_distance': '83.370971',
#   'x_coordinate': '-122.63061333333333',
#   'y_coordinate': '45.675285',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '50364',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': '50100',
#   'arrive_time': '50364',
#   'dwell': '0',
#   'location_id': '912',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '8.1219',
#   'pattern_distance': '8.2835',
#   'location_distance': '37.182974',
#   'x_coordinate': '-122.67047166666667',
#   'y_coordinate': '45.62878166666667',
#   'data_source': '2',
#   'schedule_status': '4'},
#  {'vehicle_number': '2270',
#   'leave_time': '50404',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '1',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '50404',
#   'dwell': '0',
#   'location_id': '1048',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '8.3506',
#   'pattern_distance': '8.4973',
#   'location_distance': '81.228543',
#   'x_coordinate': '-122.67505',
#   'y_coordinate': '45.62881',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '51005',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '51005',
#   'dwell': '0',
#   'location_id': '339',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '3',
#   'maximum_speed': None,
#   'train_mileage': '1.3664',
#   'pattern_distance': '1.4118',
#   'location_distance': '86.682031',
#   'x_coordinate': '-122.65816166666667',
#   'y_coordinate': '45.63312333333333',
#   'data_source': '2',
#   'schedule_status': '2'},
#  {'vehicle_number': '2270',
#   'leave_time': '51852',
#   'train': '2502',
#   'route_number': '25',
#   'direction': '0',
#   'service_key': 'W',
#   'stop_time': None,
#   'arrive_time': '51852',
#   'dwell': '0',
#   'location_id': '295',
#   'door': '0',
#   'lift': '0',
#   'ons': '0',
#   'offs': '0',
#   'estimated_load': '2',
#   'maximum_speed': None,
#   'train_mileage': '4.6833',
#   'pattern_distance': '4.7759',
#   'location_distance': '22.741124',
#   'x_coordinate': '-122.63318166666667',
#   'y_coordinate': '45.67399666666667',
#   'data_source': '2',
#   'schedule_status': '2'},
#  ...]

# %%
df = pd.DataFrame(records)
df
# Out:
#       vehicle_number leave_time train route_number direction service_key  \
# 0               2224      31928  9004          105         0           W
# 1               2224      32402  9004          105         0           W
# 2               2224      32683  9004          105         0           W
# 3               2224      33072  9004          105         0           W
# 4               2224      33116  9004          105         0           W
# ...              ...        ...   ...          ...       ...         ...
# 27400           2245      57142  9052          190      None           W
# 27401        1254300      64761  6451          164      None           W
# 27402           4025      74174  6552           65      None           W
# 27403           2228      66234  3454          105      None           W
# 27404           2247      70109  5752          105      None           W
#
#       stop_time arrive_time dwell location_id  ... offs estimated_load  \
# 0         31920       31928     0         940  ...    0              1
# 1         32400       32402     0        None  ...    0              1
# 2         32640       32683     0        None  ...    0              1
# 3         33000       33072     0         908  ...    0              1
# 4          None       33116     0         910  ...    0              1
# ...         ...         ...   ...         ...  ...  ...            ...
# 27400     57180       57142     0         798  ...    4              0
# 27401     64980       64761     0         492  ...    0              0
# 27402     74460       74174     0         492  ...    0              0
# 27403     66360       66234     0         177  ...    0              0
# 27404     70860       70109     0         177  ...    0              0
#
#       maximum_speed train_mileage pattern_distance location_distance  \
# 0              None             0                0         14.270249
# 1              None         2.854            2.849         13.309048
# 2              None        6.7711           6.7872         75.045969
# 3              None       10.7261          10.8063        103.588889
# 4              None       10.9256          11.0008         64.894642
# ...             ...           ...              ...               ...
# 27400          None             0             None          58.34651
# 27401          None             0             None        188.778819
# 27402          None             0             None        377.815826
# 27403          None             0             None         178.47212
# 27404          None             0             None      11309.131685
#
#               x_coordinate        y_coordinate data_source schedule_status
# 0      -122.67722499999999           45.519565           2               5
# 1               -122.66536             45.5231           1               4
# 2      -122.67852833333333   45.57750166666667           1               4
# 3      -122.67055833333333   45.62878166666667           2               4
# 4      -122.67050666666667  45.631503333333335           2               2
# ...                    ...                 ...         ...             ...
# 27400  -122.68210333333333   45.49664666666666           2               0
# 27401          -122.505445   45.59466333333334           2               0
# 27402  -122.50615166666667           45.594895           2               0
# 27403          -122.660525           45.721445           2               0
# 27404  -122.66370333333333            45.69062           2               0
#
# [27405 rows x 23 columns]
